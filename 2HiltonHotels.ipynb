# %% [markdown]
# # AfterWork Data Science: Data Visualisation with Python Project

# %% [markdown]
# ## 1. Defining the Question

# %% [markdown]
# ### a) Specifying the Data Analysis Question

# %% [markdown]
# Specify the reasearch question that you'll be answering.

# %% [markdown]
# > i.e. Provide strategy recommendations that will lead to revenue growth.

# %% [markdown]
# ### b) Defining the Metric for Success

# %% [markdown]
# The solutions to the following questions will help us answer our research question:
#
# 1. When is the best time of year to book a hotel room?
# 2. When is the optimal length of stay in order to get the best daily rate?
# 3. How will you know if a hotel was likely to receive a disproportionately high number of special requests?

# %% [markdown]
# ### c) Understanding the context

# %% [markdown]
# Provide some background information....

# %% [markdown]
# ### d) Recording the Experimental Design

# %% [markdown]
# Describe the steps/approach that you will use to answer the given question.

# %% [markdown]
# ### e) Data Relevance

# %% [markdown]
# How relevant was the provided data?

# %% [markdown]
# ## 2. Reading the Data

# %%
# Load the data below
# --- 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns

HiltonHotels = pd.read_csv("hotel_bookings.csv")

# %%
# Checking the first 5 rows of data
# ---
HiltonHotels.head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 32 columns]

# %%
# Checking the last 5 rows of data
# ---
# YOUR CODE GOES BELOW
HiltonHotels.tail()
# Out:
#              hotel  is_canceled  ...  reservation_status  reservation_status_date
# 119385  City Hotel            0  ...           Check-Out               2017-09-06
# 119386  City Hotel            0  ...           Check-Out               2017-09-07
# 119387  City Hotel            0  ...           Check-Out               2017-09-07
# 119388  City Hotel            0  ...           Check-Out               2017-09-07
# 119389  City Hotel            0  ...           Check-Out               2017-09-07
#
# [5 rows x 32 columns]

# %%
# Sample 10 rows of data
# ---
# YOUR CODE GOES BELOW
HiltonHotels.sample(10)
# Out:
#                hotel  is_canceled  ...  reservation_status  reservation_status_date
# 64023     City Hotel            1  ...            Canceled               2017-02-08
# 102937    City Hotel            0  ...           Check-Out               2016-12-10
# 44983     City Hotel            1  ...            Canceled               2015-07-06
# 53896     City Hotel            1  ...            Canceled               2016-03-29
# 19576   Resort Hotel            0  ...           Check-Out               2015-12-28
# 112144    City Hotel            0  ...           Check-Out               2017-05-21
# 26606   Resort Hotel            0  ...           Check-Out               2016-08-06
# 114797    City Hotel            0  ...           Check-Out               2017-06-27
# 106105    City Hotel            0  ...           Check-Out               2017-02-21
# 1160    Resort Hotel            1  ...            Canceled               2015-08-10
#
# [10 rows x 32 columns]

# %%
# Checking number of rows and columns
# ---
# YOUR CODE GOES BELOW
HiltonHotels.shape
# Out:
# (119390, 32)

# %%
# Checking datatypes
# ---
# YOUR CODE GOES BELOW
HiltonHotels.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# Record your observations below:
#
# *   Observation 1
# *   Observation 2

# %% [markdown]
# ## 3. External Data Source Validation

# %% [markdown]
# The data is originally from the article Hotel Booking Demand Datasets, by Nuno Antonio, Ana Almeida, and Luis Nunes for Data in Brief, Volume 22, February 2019.

# %% [markdown]
# ## 4. Data Preparation

# %% [markdown]
# ### Performing Data Cleaning

# %%
# Checking datatypes and missing entries of all the variables
# ---
# YOUR CODE GOES BELOW
HiltonHotels.isnull().any()
# Out:
# hotel                             False
# is_canceled                       False
# lead_time                         False
# arrival_date_year                 False
# arrival_date_month                False
# arrival_date_week_number          False
# arrival_date_day_of_month         False
# stays_in_weekend_nights           False
# stays_in_week_nights              False
# adults                            False
# children                           True
# babies                            False
# meal                              False
# country                            True
# market_segment                    False
# distribution_channel              False
# is_repeated_guest                 False
# previous_cancellations            False
# previous_bookings_not_canceled    False
# reserved_room_type                False
# assigned_room_type                False
# booking_changes                   False
# deposit_type                      False
# ...

# %% [markdown]
# We observe the following from our dataset:
#
# *   Observation 1
# *   Observation 2

# %%
# Checking how many duplicate rows are there in the data
# ---
# YOUR CODE GOES BELOW
sum(HiltonHotels.duplicated())
# Out:
# 31994

# %% [markdown]
# We choose to keep the duplicates because we don't have a unique identifier to actually proof that we have duplicates.

# %%
# Checking if any of the columns are all null
# ---
# YOUR CODE GOES BELOW
HiltonHotels.isnull().all()
# Out:
# hotel                             False
# is_canceled                       False
# lead_time                         False
# arrival_date_year                 False
# arrival_date_month                False
# arrival_date_week_number          False
# arrival_date_day_of_month         False
# stays_in_weekend_nights           False
# stays_in_week_nights              False
# adults                            False
# children                          False
# babies                            False
# meal                              False
# country                           False
# market_segment                    False
# distribution_channel              False
# is_repeated_guest                 False
# previous_cancellations            False
# previous_bookings_not_canceled    False
# reserved_room_type                False
# assigned_room_type                False
# booking_changes                   False
# deposit_type                      False
# ...

# %% [markdown]
# We observe the following from our dataset:
#
# *   Observation 1
# *   Observation 2

# %%
# Checking if any of the rows are all null
# ---
# YOUR CODE GOES BELOW
HiltonHotels.isnull().all(axis=1)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 119390, dtype: bool

# %% [markdown]
# We observe the following from our dataset:
#
# *   Observation 1
# *   Observation 2

# %%
# Checking the correlation of the features through the use of 
# visualizations the correlation using heatmap
# ---
# YOUR CODE GOES BELOW
HiltonHotels_corr = HiltonHotels.corr()
plt.figure(figsize=(5,4))

sns.heatmap(HiltonHotels_corr)
plt.show()

# %% [markdown]
# We observe the following from our dataset:
#
# *   Observation 1
# *   Observation 2

# %%
# Dropping company column because it has alot of missing values 
# and we won't need to answer any of our questions
# ---
# YOUR CODE GOES BELOW
HiltonHotels.drop(["company"],axis=1,inplace=True)
HiltonHotels.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# From the data variable description we see that the Distribution Channel categoricy that tells us about Booking distribution.
#
# 1. The term “TA” means “Travel Agents”
# 2. The term “TO” means “Tour Operators”
#
# This allows us to fill the missing values in the agents column with TO

# %%
# We replace the mising values i.e. for TO
# ---
# YOUR GOES BELOW
#
HiltonHotels.agent = HiltonHotels.agent.fillna(value="TO")

# %%
# We drop rows where there is no adult, baby and child as 
# these records won't help us.
# ---
# YOUR GOES BELOW
HiltonHotels.shape
HiltonHotels = HiltonHotels[pd.notnull(HiltonHotels['adults'])]
HiltonHotels.shape
# Out:
# (119390, 31)

# %%
HiltonHotels = HiltonHotels[pd.notnull(HiltonHotels['children'])]
HiltonHotels.shape
# Out:
# (119386, 31)

# %%
HiltonHotels = HiltonHotels[pd.notnull(HiltonHotels['babies'])]
HiltonHotels.shape
# Out:
# (119386, 31)

# %%
# We replace missing children values with rounded mean value
# ---
# Hint i.e. use round()
# ---
# YOUR GOES BELOW
HiltonHotels['children'] = HiltonHotels['children'].fillna(HiltonHotels['children'].mean())

# %%
HiltonHotels['children'] = HiltonHotels['children'].astype(int).round()

# %%
# Checking for missing values in the dataframe
# ---
# YOUR GOES BELOW
#
HiltonHotels.isnull().any()
# Out:
# hotel                             False
# is_canceled                       False
# lead_time                         False
# arrival_date_year                 False
# arrival_date_month                False
# arrival_date_week_number          False
# arrival_date_day_of_month         False
# stays_in_weekend_nights           False
# stays_in_week_nights              False
# adults                            False
# children                          False
# babies                            False
# meal                              False
# country                            True
# market_segment                    False
# distribution_channel              False
# is_repeated_guest                 False
# previous_cancellations            False
# previous_bookings_not_canceled    False
# reserved_room_type                False
# assigned_room_type                False
# booking_changes                   False
# deposit_type                      False
# ...

# %%
# Converting the datatypes of the following columns from float to integer
# i.e. children, company, agent
# ---
# YOUR GOES BELOW

# %% [markdown]
# ## 5. Solution Implementation

# %% [markdown]
# Here we investigate the questions that would help us with our recommendations.

# %% [markdown]
# ### 5.a) Questions

# %%
# 1. How many bookings were cancelled?
# ---
# 

# First getting the data that we need 
# ---
# YOUR GOES BELOW
# 
HiltonHotels['is_canceled'].value_counts().plot(kind='barh', figsize=(6, 3), color=['green', 'orange'])
plt.xlabel("Booking Cancelled (No = 0, Yes = 1)", labelpad=14)
plt.ylabel("Booking (%)", labelpad=14)
plt.title("Count of bookings", y=1.02);

# Then plotting a bar plot  
# ---
#

# %%
# 2. What was the booking ratio between resort hotel and city hotel?
# ---
# 

# First selecting only those booking which did not get cancelled.
# ---
#
HiltonHotels_not_canceled = HiltonHotels.copy()
indexnames = HiltonHotels_not_canceled[HiltonHotels_not_canceled['is_canceled']==1].index
HiltonHotels_not_canceled.drop(indexnames,inplace=True)


# Selecting our desired records
# ---
# YOUR GOES BELOW


HiltonHotels_not_canceled['hotel'].value_counts().plot(kind='barh', figsize=(6, 3), color=['green', 'orange'])
plt.xlabel("Count of bookings", labelpad=14)
plt.ylabel("hotel types", labelpad=14)
plt.title("Count of hotel types", y=1.02);

# %%
# 3. What was the percentage of booking for each year?
# ---
# 

# Getting our variable of interest
# ---
# YOUR GOES BELOW

HiltonHotels['arrival_date_year'].value_counts().plot(kind='barh', figsize=(6, 3),color=['green', 'orange','blue'])
plt.xlabel("count of bookings", labelpad=14)
plt.ylabel("year", labelpad=14)
plt.title("Count of bookings", y=1.02);

# %%
# Separating the data by hotel
# ---
# 
plt.subplots(figsize=(7,5))

sns.countplot(x='arrival_date_year', hue='hotel',  data=HiltonHotels_not_canceled);

# %%
# 4. Which were the most busiest months for hotels?
# ---
# 

# We would like to use our months in our x-axis so we set that
# ---
# 
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sorted_months = HiltonHotels_not_canceled['arrival_date_month'].value_counts().reindex(new_order)

x = sorted_months.index
y = sorted_months/sorted_months.sum()*100

# Plotting our visualisation
# --- 
# 
plt.figure(figsize=(18, 6))
plt.plot(x, y.values,)
plt.title("Booking Trend (Monthly)")
plt.xlabel("Months")
plt.ylabel("Booking (%)");

# %%
# Order of months
# ---
#
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']


# Select only City Hotel
# ---
#
sorted_months = HiltonHotels_not_canceled.loc[HiltonHotels_not_canceled.hotel=='City Hotel' ,'arrival_date_month'].value_counts().reindex(new_order)

x1 = sorted_months.index
y1 = sorted_months/sorted_months.sum()*100


# Select only Resort Hotel
# ---
# YOUR CODE GOES BELOW
# 
sorted_months = HiltonHotels_not_canceled.loc[HiltonHotels_not_canceled.hotel=='Resort Hotel' ,'arrival_date_month'].value_counts().reindex(new_order)

x2 = sorted_months.index
y2 = sorted_months/sorted_months.sum()*100

# Drawing the line plot
# ---
# YOUR CODE GOES BELOW
# 
plt.figure(figsize=(18, 6))
plt.plot(x1, y1.values)
plt.plot(x2, y2.values)
plt.title("Booking Trend (Monthly)")
plt.xlabel("Months")
plt.ylabel("Booking (%)");

# %%
# 5. From which top 3 countries did most guests come from?
# --- 
# YOUR GOES BELOW
#
TopCountries = HiltonHotels.groupby(['country']).count()

TopCountries.sort_values(by='arrival_date_month',ascending=False)
# Out:
#          hotel  is_canceled  ...  reservation_status  reservation_status_date
# country                      ...
# PRT      48586        48586  ...               48586                    48586
# GBR      12129        12129  ...               12129                    12129
# FRA      10415        10415  ...               10415                    10415
# ESP       8568         8568  ...                8568                     8568
# DEU       7287         7287  ...                7287                     7287
# ...        ...          ...  ...                 ...                      ...
# MLI          1            1  ...                   1                        1
# MMR          1            1  ...                   1                        1
# MRT          1            1  ...                   1                        1
# SMR          1            1  ...                   1                        1
# PYF          1            1  ...                   1                        1
#
# ...

# %%
# 6.a) How long do most people stay in hotels?
#   b) By city and resort? Separate the data by hotel
# ---
# 

# Calculating the total nights
# ---
# Hint: total_nights = stays_in_weekend_nights + stay_in_week_nights.
# Also, only select 10 records.
# ---
#
total_nights = HiltonHotels_not_canceled['stays_in_weekend_nights']+ HiltonHotels_not_canceled['stays_in_week_nights']


# ---
# YOUR CODE GOES BELOW
# ---
#
HiltonHotels_not_canceled['total_nights'] = total_nights
HiltonHotels_not_canceled['total_nights'].sort_values(ascending=False).head(10)
# Out:
# 14038     69
# 14037     60
# 101794    57
# 33924     56
# 88017     49
# 54704     48
# 1655      46
# 32589     45
# 106561    43
# 34898     42
# Name: total_nights, dtype: int64

# %%
# b) By city and resort? 
# Hint: Separate the data by hotel
# ---
# YOUR CODE GOES BELOW
# ---
#
plt.subplots(figsize=(7,5))

sns.countplot(x='total_nights', hue='hotel',  data=HiltonHotels_not_canceled);

# %%
# 7. Which was the most booked accommodation type (Single, Couple, Family)?
# ---
#

# Select Single, Couple, Multiple Adults and Family 

# Single
# ---
#
single   = HiltonHotels_not_canceled[(df_not_canceled.adults==1) & (HiltonHotels_not_canceled.children==0) & (HiltonHotels_not_canceled.babies==0)]

# Couple
# ---
# YOUR GOES BELOW
#
couple   = HiltonHotels_not_canceled[(df_not_canceled.adults==2) & (HiltonHotels_not_canceled.children==0) & (HiltonHotels_not_canceled.babies==0)]

# Family
# ---
# YOUR GOES BELOW
#
Family   = HiltonHotels_not_canceled[(df_not_canceled.adults>=2) & (HiltonHotels_not_canceled.children>=0) & (HiltonHotels_not_canceled.babies>=0)]

# Then make the list of category names, and their total percentage
# ---
# YOUR GOES BELOW
#


# Performing our plot
# --- 
# YOUR GOES BELOW
#

# %% [markdown]
# ### 5.b) Recommendations

# %% [markdown]
# From the above analysis, below are our recommendations:
#
# 1.
# 2.

# %% [markdown]
# ## 6. Challenging your Solution

# %% [markdown]
# During this step, we review our solution and implement  approaches that could potentially provide a better outcome. In our case, we could propose the following question that wasn't answered in our solution because it couldn't have greatly contributed to our recommendation.

# %%
# When should hotels provide special offers?
# ---
# YOUR GOES BELOW
#

# %% [markdown]
# Our observations:
#
# 1.
# 2.
#
#
# How does this observation tie to our solution?

# %% [markdown]
# ## 7. Follow up questions

# %% [markdown]
# During this step, you rethink and propose other ways that you can improve your solution.

# %% [markdown]
# ### a). Did we have the right data?

# %% [markdown]
# ### b). Do we need other data to answer our question?

# %% [markdown]
# You can look into the questions you brainstormed that you weren't taken into account during analysis due to a lack of data. Were those questions important to have been left out  of your analysis?

# %% [markdown]
# ### c). Did we have the right question?

# %% [markdown]
# Were there any other questions that we needed to have answered?
